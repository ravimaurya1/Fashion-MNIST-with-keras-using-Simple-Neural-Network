# %% [markdown]
# ### Import Essential Library

# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Now import image dataset
#   <img src="images/mnist.png"
#          alt="Fashion MNIST sprite"  width="600">
#    <br>
#    <br>
#    MNIST image dataset have grayscale image in 10 categories.

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
#
# The train_images and train_labels arrays are the training set—the data the model uses to learn.

# %% [markdown]
# ## Analyze MNIST Dataset

# %%
print (train_images.shape)
# Out:
# (60000, 28, 28)

# %% [markdown]
#  60000 training images of 28x28 pixel

# %%
print (train_labels.shape)
# Out:
# (60000,)

# %%
print (test_images.shape)
# Out:
# (10000, 28, 28)

# %% [markdown]
# 10000 images for testing

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>

# %%
class_labels=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %% [markdown]
# ## Preprocess the Dataset

# %%
plt.figure()
plt.imshow(train_images[3],cmap=plt.cm.binary)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Normalize Dataset

# %%
train_images1=train_images/255.0
test_images1=test_images/255.0

# %% [markdown]
# ## Show 25 images of our Dataset

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_labels[train_labels[i]])
plt.show()

# %% [markdown]
# ## Build the Neural Network

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# ## Convert target set to categorical vector

# %%
from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels  = to_categorical(test_labels)

# %% [markdown]
# ## Compile the model

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Train the model

# %%
model.fit(train_images1,train_labels,epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 12s 207us/step - loss: 0.7838 - acc: 0.8064
# Epoch 2/5
# 60000/60000 [==============================] - 12s 205us/step - loss: 0.3978 - acc: 0.8595
# Epoch 3/5
# 60000/60000 [==============================] - 12s 207us/step - loss: 0.3636 - acc: 0.8700
# Epoch 4/5
# 60000/60000 [==============================] - 13s 212us/step - loss: 0.3374 - acc: 0.8789
# Epoch 5/5
# 60000/60000 [==============================] - 13s 214us/step - loss: 0.3215 - acc: 0.8838

# %% [markdown]
# So here Accuracy of model is 88.38% on our training set

# %% [markdown]
# ## Evaluate accuracy on testing set

# %%
test_loss, test_acc = model.evaluate(test_images1, test_labels)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 99us/step
# Test accuracy: 0.8688

# %% [markdown]
# ## Now make prediction

# %%
predictions = model.predict(np.expand_dims(test_images1[9], axis=0))
plt.imshow(test_images[9],cmap=plt.cm.binary)
print ("Prediction=",class_labels[np.argmax(predictions)],np.max(predictions)*100,"%")
print ("Actual=",class_labels[np.argmax(test_labels[9])])
# Out:
# Prediction= Sneaker 99.98258948326111 %
# Actual= Sneaker

# %% [markdown]
# ## Lets predict for 10 images

# %%
num_rows = 10
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*num_cols, 2*num_rows))
plt.grid(False)
plt.axis('off')
for i in range(num_images):
    plt.subplot(num_rows, num_cols, i+1)
    plt.xticks([])
    plt.yticks([])
    predictions = model.predict(np.expand_dims(test_images1[i], axis=0))
    plt.imshow(test_images[i],cmap=plt.cm.binary)
    xd="Prediction="+str(class_labels[np.argmax(predictions)])+'\n'+str(round(np.max(predictions)*100,2))#+"%"+"Actual="+str(class_labels[np.argmax(test_labels[i])])
    plt.xlabel(xd)
